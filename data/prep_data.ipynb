# %%
import json
import typing as t

# data prep
import pandas as pd
import numpy as np

# for creating image vector embeddings
from PIL import Image
from img2vec_pytorch import Img2Vec

# for creating semantic (text-based) vector embeddings
from sentence_transformers import SentenceTransformer

# %%
import os

os.getcwd()
# Out:
# '/Users/robert.shelton/Documents/redis-product-search/data'

# %%
# load in data and clean data types and drop null rows
metadata = pd.read_csv("./product-images-sm/styles.csv", on_bad_lines='skip')
metadata.dropna(inplace=True)
metadata["year"] = metadata["year"].astype(int)
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44077 entries, 0 to 44423
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  44077 non-null  int64
#  1   gender              44077 non-null  object
#  2   masterCategory      44077 non-null  object
#  3   subCategory         44077 non-null  object
#  4   articleType         44077 non-null  object
#  5   baseColour          44077 non-null  object
#  6   season              44077 non-null  object
#  7   year                44077 non-null  int64
#  8   usage               44077 non-null  object
#  9   productDisplayName  44077 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 3.7+ MB

# %%
metadata["product_text"] = metadata.apply(lambda row: f"name {row['productDisplayName']} category {row['masterCategory']} subcategory {row['subCategory']} color {row['baseColour']} gender {row['gender']}".lower(), axis=1)
metadata.rename({"id":"product_id"}, inplace=True, axis=1)

metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44077 entries, 0 to 44423
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          44077 non-null  int64
#  1   gender              44077 non-null  object
#  2   masterCategory      44077 non-null  object
#  3   subCategory         44077 non-null  object
#  4   articleType         44077 non-null  object
#  5   baseColour          44077 non-null  object
#  6   season              44077 non-null  object
#  7   year                44077 non-null  int64
#  8   usage               44077 non-null  object
#  9   productDisplayName  44077 non-null  object
#  10  product_text        44077 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 4.0+ MB

# %%
# check out one of the texts we will use to create semantic embeddings
metadata["product_text"][0]
# Out:
# 'name turtle check men navy blue shirt category apparel subcategory topwear color navy blue gender men'

# %%
# Resnet-18 to create image embeddings
img2vec = Img2Vec(cuda=False)

# bert variant to create text embeddings
model = SentenceTransformer('sentence-transformers/all-distilroberta-v1')
# Out:
# /Users/robert.shelton/.pyenv/versions/3.11.9/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/robert.shelton/.pyenv/versions/3.11.9/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /Users/robert.shelton/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:03<00:00, 15.2MB/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.3k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /Users/robert.shelton/.pyenv/versions/3.11.9/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/653 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/328M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/333 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
def get_batch(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def generate_image_vectors(products, image_base_path, batch_size=1000):
    output_dict={}

    for batch in get_batch(products, batch_size):
        product_ids = batch['product_id'].values.tolist()
        image_filenames = [image_base_path + "/" + str(_id) + ".jpg" for _id in product_ids]
        images=[]
        converted=[]

        for img_path, _id in zip(image_filenames, product_ids):
            try:
                img = Image.open(img_path).convert('RGB')
                img = img.resize((224, 224))
                images.append(img)
                converted.append(_id)
            except:
                #unable_to_convert -> skip to the next image
                continue

        #Generate vectors for all images in this batch
        vec_list = img2vec.get_vec(images)

        #update the dictionary to be returned
        batch_dict= dict(zip(converted, vec_list))
        output_dict.update(batch_dict)
        print(f"Processed {str(batch_size)} product images")

    return output_dict

def generate_text_vectors(products_df):
    text_vectors = {}
    # generate text vector
    for index, row in products_df.iterrows():
        text_vector = model.encode(row["product_text"])
        text_vectors[row["product_id"]] = text_vector.astype(np.float32)
        if index % 1000 == 0:
            print(f"Processed {str(index)} product text fields")
    return text_vectors

# combine into a single json file
def combine_vector_dicts(txt_vectors, img_vectors, products):
    product_vectors = []
    for _, row in products.iterrows():
        try:
            _id = row["product_id"]
            text_vector = txt_vectors[_id].tolist()
            img_vector = img_vectors[_id].tolist()
            vector_dict = {
                "text_vector": text_vector,
                "img_vector": img_vector,
                "product_id": _id
            }
            product_vectors.append(vector_dict)
        except KeyError:
            continue
    return product_vectors

def write_product_vector_json(vector_dict):
    product_vector_json = json.dumps(vector_dict)
    with open("./product_vectors.json", "w") as f:
        f.write(product_vector_json)

def write_product_metadata_json(metadata_df):
    products = []
    for _, row in metadata_df.iterrows():
        product = {
            "product_id": row["product_id"],
            # create a text based representation to create a semantic embedding with
            "product_metadata": {
                "name": row["productDisplayName"],
                "gender": row["gender"],
                "master_category": row["masterCategory"],
                "sub_category": row["subCategory"],
                "article_type": row["articleType"],
                "base_color": row["baseColour"],
                "season": row["season"],
                "year": row["year"],
                "usage": row["usage"]
            }
        }
        products.append(product)

    products_json = json.dumps(products)
    with open("./product_metadata.json", "w") as f:
        f.write(products_json)
    return products

# %%
data_path = "./product-images-sm/images"
num_products = 1000
image_vectors = generate_image_vectors(metadata[:num_products], data_path, batch_size=1000)
text_vectors = generate_text_vectors(metadata[:num_products])
vector_dict = combine_vector_dicts(text_vectors, image_vectors, metadata)
write_product_vector_json(vector_dict)
products_meta = write_product_metadata_json(metadata[:num_products])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 3
#       1 data_path = "./product-images-sm/images"
#       2 num_products = 1000
# ----> 3 image_vectors = generate_image_vectors(metadata[:num_products], data_path, batch_size=1000)
#       4 text_vectors = generate_text_vectors(metadata[:num_products])
#       5 vector_dict = combine_vector_dicts(text_vectors, image_vectors, metadata)
#
# Cell In[7], line 24, in generate_image_vectors(products, image_base_path, batch_size)
#      21         continue
#      23 #Generate vectors for all images in this batch
# ---> 24 vec_list = img2vec.get_vec(images)
#      26 #update the dictionary to be returned
#      27 batch_dict= dict(zip(converted, vec_list))
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/img2vec_pytorch/img_to_vec.py:70, in Img2Vec.get_vec(self, img, tensor)
#      68 h = self.extraction_layer.register_forward_hook(copy_data)
#      69 with torch.no_grad():
# ---> 70     h_x = self.model(images)
#      71 h.remove()
#      73 if tensor:
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/torchvision/models/resnet.py:285, in ResNet.forward(self, x)
#     284 def forward(self, x: Tensor) -> Tensor:
# --> 285     return self._forward_impl(x)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/torchvision/models/resnet.py:274, in ResNet._forward_impl(self, x)
#     271 x = self.maxpool(x)
#     273 x = self.layer1(x)
# --> 274 x = self.layer2(x)
#     275 x = self.layer3(x)
#     276 x = self.layer4(x)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/torchvision/models/resnet.py:92, in BasicBlock.forward(self, x)
#      89 def forward(self, x: Tensor) -> Tensor:
#      90     identity = x
# ---> 92     out = self.conv1(x)
#      93     out = self.bn1(out)
#      94     out = self.relu(out)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
products_meta = write_product_metadata_json(metadata[:num_products])
[v["product_id"] for v in vector_dict] == list(metadata["product_id"][:1000])
# Out:
# True

# %%
products_meta
# Out:
# [{'product_id': 15970,
#   'product_metadata': {'name': 'Turtle Check Men Navy Blue Shirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Shirts',
#    'base_color': 'Navy Blue',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 39386,
#   'product_metadata': {'name': 'Peter England Men Party Blue Jeans',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Bottomwear',
#    'article_type': 'Jeans',
#    'base_color': 'Blue',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 59263,
#   'product_metadata': {'name': 'Titan Women Silver Watch',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'Silver',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 21379,
#   'product_metadata': {'name': 'Manchester United Men Solid Black Track Pants',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Bottomwear',
#    'article_type': 'Track Pants',
#    'base_color': 'Black',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 53759,
#   'product_metadata': {'name': 'Puma Men Grey T-shirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Grey',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 1855,
#   'product_metadata': {'name': 'Inkfruit Mens Chain Reaction T-shirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Grey',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 30805,
#   'product_metadata': {'name': 'Fabindia Men Striped Green Shirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Shirts',
#    'base_color': 'Green',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Ethnic'}},
#  {'product_id': 26960,
#   'product_metadata': {'name': 'Jealous 21 Women Purple Shirt',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Shirts',
#    'base_color': 'Purple',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 29114,
#   'product_metadata': {'name': 'Puma Men Pack of 3 Socks',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Socks',
#    'article_type': 'Socks',
#    'base_color': 'Navy Blue',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 30039,
#   'product_metadata': {'name': 'Skagen Men Black Watch',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'Black',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 9204,
#   'product_metadata': {'name': 'Puma Men Future Cat Remix SF Black Casual Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Casual Shoes',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 48123,
#   'product_metadata': {'name': 'Fossil Women Black Huarache Weave Belt',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Belts',
#    'article_type': 'Belts',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 18653,
#   'product_metadata': {'name': 'Fila Men Cush Flex Black Slippers',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Flip Flops',
#    'article_type': 'Flip Flops',
#    'base_color': 'Black',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 47957,
#   'product_metadata': {'name': 'Murcia Women Blue Handbag',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Bags',
#    'article_type': 'Handbags',
#    'base_color': 'Blue',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 46885,
#   'product_metadata': {'name': 'Ben 10 Boys Navy Blue Slippers',
#    'gender': 'Boys',
#    'master_category': 'Footwear',
#    'sub_category': 'Flip Flops',
#    'article_type': 'Flip Flops',
#    'base_color': 'Navy Blue',
#    'season': 'Fall',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 12369,
#   'product_metadata': {'name': 'Reid & Taylor Men Check Purple Shirts',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Shirts',
#    'base_color': 'Purple',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Formal'}},
#  {'product_id': 29928,
#   'product_metadata': {'name': 'Police Men Black Dial Watch PL12889JVSB',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'Black',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 42419,
#   'product_metadata': {'name': 'Gini and Jony Girls Knit White Top',
#    'gender': 'Girls',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tops',
#    'base_color': 'White',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 51832,
#   'product_metadata': {'name': 'Bwitch Beige Full-Coverage Bra BW335',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Innerwear',
#    'article_type': 'Bra',
#    'base_color': 'Beige',
#    'season': 'Summer',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 47359,
#   'product_metadata': {'name': 'Baggit Women Brown Handbag',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Bags',
#    'article_type': 'Handbags',
#    'base_color': 'Brown',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 17429,
#   'product_metadata': {'name': 'CASIO G-Shock Men Black Digital Watch G-7710-1DR G223',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'Black',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 12967,
#   'product_metadata': {'name': 'ADIDAS Men Spry M Black Sandals',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Sandal',
#    'article_type': 'Sandals',
#    'base_color': 'Black',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 6842,
#   'product_metadata': {'name': 'Timberland Unisex Rubber Sole Brush Shoe Accessories',
#    'gender': 'Unisex',
#    'master_category': 'Accessories',
#    'sub_category': 'Shoe Accessories',
#    'article_type': 'Shoe Accessories',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 13089,
#   'product_metadata': {'name': 'ADIDAS Men Lfc Auth Hood Grey Sweatshirts',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Sweatshirts',
#    'base_color': 'Grey',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Sports'}},
#  {'product_id': 18461,
#   'product_metadata': {'name': 'David Beckham Signature Men Deos',
#    'gender': 'Men',
#    'master_category': 'Personal Care',
#    'sub_category': 'Fragrance',
#    'article_type': 'Deodorant',
#    'base_color': 'White',
#    'season': 'Spring',
#    'year': 2017,
#    'usage': 'Casual'}},
#  {'product_id': 9036,
#   'product_metadata': {'name': 'Buckaroo Men Flores Black Formal Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Formal Shoes',
#    'base_color': 'Black',
#    'season': 'Winter',
#    'year': 2011,
#    'usage': 'Formal'}},
#  {'product_id': 48311,
#   'product_metadata': {'name': 'Pitaraa Women Bronze Beaded Bracelet',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Jewellery',
#    'article_type': 'Bracelet',
#    'base_color': 'Bronze',
#    'season': 'Winter',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 7990,
#   'product_metadata': {'name': "Fila Men's Round Neck Navy Blue T-shirt",
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Navy Blue',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Sports'}},
#  {'product_id': 56019,
#   'product_metadata': {'name': 'Colorbar Soft Touch Show Stopper Copper Lipstick 037',
#    'gender': 'Women',
#    'master_category': 'Personal Care',
#    'sub_category': 'Lips',
#    'article_type': 'Lipstick',
#    'base_color': 'Brown',
#    'season': 'Spring',
#    'year': 2017,
#    'usage': 'Casual'}},
#  {'product_id': 21977,
#   'product_metadata': {'name': 'Murcia Women Casual Brown Handbag',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Bags',
#    'article_type': 'Handbags',
#    'base_color': 'Brown',
#    'season': 'Winter',
#    'year': 2015,
#    'usage': 'Casual'}},
#  {'product_id': 37812,
#   'product_metadata': {'name': 'John Players Men Navy Blue Shirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Shirts',
#    'base_color': 'Navy Blue',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Formal'}},
#  {'product_id': 4729,
#   'product_metadata': {'name': "Disney Kids Boy's Crew Sea Life Sialing Green Teen Kidswear",
#    'gender': 'Boys',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Green',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 56825,
#   'product_metadata': {'name': 'John Players Men Brown Shirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Shirts',
#    'base_color': 'Brown',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 39988,
#   'product_metadata': {'name': 'Gas Men Europa White Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Casual Shoes',
#    'base_color': 'White',
#    'season': 'Winter',
#    'year': 2014,
#    'usage': 'Casual'}},
#  {'product_id': 59051,
#   'product_metadata': {'name': 'Carlton London Women Black & Gold Toned Flats',
#    'gender': 'Women',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Flats',
#    'base_color': 'Black',
#    'season': 'Winter',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 20099,
#   'product_metadata': {'name': 'Diva Women Embroided Green Kurta',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Kurtas',
#    'base_color': 'Green',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Ethnic'}},
#  {'product_id': 58183,
#   'product_metadata': {'name': 'Rocky S Women White Handbag',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Bags',
#    'article_type': 'Handbags',
#    'base_color': 'White',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 29742,
#   'product_metadata': {'name': 'Kiara Women Teal Handbag',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Bags',
#    'article_type': 'Handbags',
#    'base_color': 'Teal',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 51658,
#   'product_metadata': {'name': 'Fossil Women Copper Chronograph Watch CH2589',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'Copper',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 3954,
#   'product_metadata': {'name': "Jealous 21 Women's Pink T-shirt",
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Pink',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 18839,
#   'product_metadata': {'name': 'Peter England Men Formal Black Belt',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Belts',
#    'article_type': 'Belts',
#    'base_color': 'Black',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Formal'}},
#  {'product_id': 2886,
#   'product_metadata': {'name': 'Catwalk Women Leather Brown Flats',
#    'gender': 'Women',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Flats',
#    'base_color': 'Brown',
#    'season': 'Winter',
#    'year': 2015,
#    'usage': 'Casual'}},
#  {'product_id': 23278,
#   'product_metadata': {'name': 'Maxima Ssteele Men Off White Watch',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'Off White',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 28690,
#   'product_metadata': {'name': 'W Women Printed Beige Kurta',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Kurtas',
#    'base_color': 'Beige',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Ethnic'}},
#  {'product_id': 8580,
#   'product_metadata': {'name': 'Scullers Men  Grey Waistcoat',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Waistcoat',
#    'base_color': 'Grey',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 3168,
#   'product_metadata': {'name': "Nike Men's Incinerate MSL White Blue Shoe",
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Sports Shoes',
#    'base_color': 'White',
#    'season': 'Fall',
#    'year': 2010,
#    'usage': 'Sports'}},
#  {'product_id': 18005,
#   'product_metadata': {'name': 'Puma Men Long Logo Black Bermuda',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Bottomwear',
#    'article_type': 'Shorts',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Sports'}},
#  {'product_id': 17871,
#   'product_metadata': {'name': 'Levis Men Boxer Maroon Brief',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Innerwear',
#    'article_type': 'Briefs',
#    'base_color': 'Maroon',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 9452,
#   'product_metadata': {'name': 'John Miller Men Stripes White Red Shirts',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Shirts',
#    'base_color': 'Red',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Formal'}},
#  {'product_id': 38402,
#   'product_metadata': {'name': 'Baggit Women Hood Dabang Black Belt',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Belts',
#    'article_type': 'Belts',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 44984,
#   'product_metadata': {'name': 'Maxima Women White Dial Watch',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'White',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 10268,
#   'product_metadata': {'name': 'Clarks Men Hang Work Leather Black Formal Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Formal Shoes',
#    'base_color': 'Black',
#    'season': 'Fall',
#    'year': 2012,
#    'usage': 'Formal'}},
#  {'product_id': 45856,
#   'product_metadata': {'name': 'Vishudh Women Brown Kurta',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Kurtas',
#    'base_color': 'Brown',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Ethnic'}},
#  {'product_id': 32138,
#   'product_metadata': {'name': 'Playboy Men Blue Titanium Briefs',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Innerwear',
#    'article_type': 'Briefs',
#    'base_color': 'Blue',
#    'season': 'Summer',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 59435,
#   'product_metadata': {'name': 'Arrow Men Black Formal Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Formal Shoes',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Formal'}},
#  {'product_id': 5891,
#   'product_metadata': {'name': "Puma Men's Stripe Polo Black T-shirt",
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 38630,
#   'product_metadata': {'name': 'Nike Women Purple Polo T-shirt',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Purple',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 4943,
#   'product_metadata': {'name': "Gini and Jony Boy's Kaleb White Brown Kidswear",
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Shirts',
#    'base_color': 'White',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 11188,
#   'product_metadata': {'name': 'Carrera Men Dial steel finish strap Silver Watches',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'Silver',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 10866,
#   'product_metadata': {'name': 'Wrangler Men Motor Rider Red T-Shirts',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Red',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 59607,
#   'product_metadata': {'name': 'FNF Pink & Grey Wedding Collection Sari',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Saree',
#    'article_type': 'Sarees',
#    'base_color': 'Grey',
#    'season': 'Fall',
#    'year': 2012,
#    'usage': 'Ethnic'}},
#  {'product_id': 15528,
#   'product_metadata': {'name': 'Puma Men Scribble Black Tshirts',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Black',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 45258,
#   'product_metadata': {'name': 'CASIO EDIFICE Men Black Dial Chronograph Watch ED60',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'Black',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 42841,
#   'product_metadata': {'name': 'French Connection Women Beige Handbag',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Bags',
#    'article_type': 'Handbags',
#    'base_color': 'Beige',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 22198,
#   'product_metadata': {'name': 'Timberland Men Black Casual Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Casual Shoes',
#    'base_color': 'Black',
#    'season': 'Fall',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 29570,
#   'product_metadata': {'name': 'Vans Men Classic Slip-On Purple & Black Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Casual Shoes',
#    'base_color': 'Purple',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 43993,
#   'product_metadata': {'name': 'Police Women Passion Perfume',
#    'gender': 'Women',
#    'master_category': 'Personal Care',
#    'sub_category': 'Fragrance',
#    'article_type': 'Perfume and Body Mist',
#    'base_color': 'Pink',
#    'season': 'Spring',
#    'year': 2017,
#    'usage': 'Casual'}},
#  {'product_id': 6628,
#   'product_metadata': {'name': "ADIDAS Men's Lowell White Silver Shoe",
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Sports Shoes',
#    'base_color': 'White',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Sports'}},
#  {'product_id': 54924,
#   'product_metadata': {'name': 'Do U Speak Green Men Blue Shorts',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Bottomwear',
#    'article_type': 'Shorts',
#    'base_color': 'Blue',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 26538,
#   'product_metadata': {'name': 'ID Men Red Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Casual Shoes',
#    'base_color': 'Red',
#    'season': 'Fall',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 35913,
#   'product_metadata': {'name': 'Peperone Women Black & White Handbag',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Bags',
#    'article_type': 'Handbags',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 49495,
#   'product_metadata': {'name': 'Vans Men Khaki Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Casual Shoes',
#    'base_color': 'Khaki',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 9660,
#   'product_metadata': {'name': 'Indigo Nation Men Reversible Bling Pink Shirts',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Shirts',
#    'base_color': 'Pink',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 2288,
#   'product_metadata': {'name': 'Nike Women Black T-shirt',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Black',
#    'season': 'Fall',
#    'year': 2010,
#    'usage': 'Sports'}},
#  {'product_id': 23876,
#   'product_metadata': {'name': 'ADIDAS Men Blue Sweatshirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Sweatshirts',
#    'base_color': 'Blue',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 18237,
#   'product_metadata': {'name': 'Manchester United Men Solid Red Tshirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Red',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 54118,
#   'product_metadata': {'name': 'Rocia Women Black Flats',
#    'gender': 'Women',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Heels',
#    'base_color': 'Black',
#    'season': 'Winter',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 2872,
#   'product_metadata': {'name': 'Catwalk Women Leather Flats',
#    'gender': 'Women',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Heels',
#    'base_color': 'Brown',
#    'season': 'Winter',
#    'year': 2015,
#    'usage': 'Casual'}},
#  {'product_id': 49653,
#   'product_metadata': {'name': 'Mineral Women Green Top',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tops',
#    'base_color': 'Green',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 8574,
#   'product_metadata': {'name': 'Crocs Dora Boots Pink Sandals',
#    'gender': 'Women',
#    'master_category': 'Footwear',
#    'sub_category': 'Sandal',
#    'article_type': 'Sandals',
#    'base_color': 'Pink',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 16957,
#   'product_metadata': {'name': 'Image Men Sunglasses',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Eyewear',
#    'article_type': 'Sunglasses',
#    'base_color': 'Black',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 19123,
#   'product_metadata': {'name': 'Lotto Men XL Water Man Silver Slippers',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Flip Flops',
#    'article_type': 'Flip Flops',
#    'base_color': 'Silver',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 13419,
#   'product_metadata': {'name': 'United Colors of Benetton Men Solid Pink Polo T-shirts',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Pink',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 17885,
#   'product_metadata': {'name': 'Levis Men Comfort Style Grey Innerwear Vest',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Innerwear',
#    'article_type': 'Innerwear Vests',
#    'base_color': 'Grey',
#    'season': 'Summer',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 43369,
#   'product_metadata': {'name': 'Reebok Men Black Possession Flip Flops',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Flip Flops',
#    'article_type': 'Flip Flops',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2013,
#    'usage': 'Casual'}},
#  {'product_id': 48781,
#   'product_metadata': {'name': 'Lucera Women Silver Pendant',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Jewellery',
#    'article_type': 'Pendant',
#    'base_color': 'Silver',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 44970,
#   'product_metadata': {'name': 'Maxima Men White Dial Analog Chronograph Watch',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'White',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 39524,
#   'product_metadata': {'name': 'Peter England Unisex Orange Sleeve Bag',
#    'gender': 'Unisex',
#    'master_category': 'Accessories',
#    'sub_category': 'Bags',
#    'article_type': 'Laptop Bag',
#    'base_color': 'Orange',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 33822,
#   'product_metadata': {'name': 'Puma Men Axis White & Grey Sports Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Sports Shoes',
#    'base_color': 'White',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Sports'}},
#  {'product_id': 58513,
#   'product_metadata': {'name': 'Tonga Women Maroon Top',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tops',
#    'base_color': 'Off White',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 25947,
#   'product_metadata': {'name': 'Femella Women Brown Scarf',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Scarves',
#    'article_type': 'Scarves',
#    'base_color': 'Brown',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 5865,
#   'product_metadata': {'name': "ADIDAS Men's Twelve Faster T-shirt",
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 39716,
#   'product_metadata': {'name': 'Arrow Woman Women Blue Dress',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Dress',
#    'article_type': 'Dresses',
#    'base_color': 'Blue',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 25349,
#   'product_metadata': {'name': 'Levis Men Red Brief',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Innerwear',
#    'article_type': 'Briefs',
#    'base_color': 'Red',
#    'season': 'Summer',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 11940,
#   'product_metadata': {'name': 'Ganuchi Men Casual Black Sandals',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Sandal',
#    'article_type': 'Sandals',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 55802,
#   'product_metadata': {'name': 'SDL by Sweet Dreams Women Green Printed Night Suit S11-3124',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Loungewear and Nightwear',
#    'article_type': 'Night suits',
#    'base_color': 'White',
#    'season': 'Summer',
#    'year': 2017,
#    'usage': 'Casual'}},
#  {'product_id': 29584,
#   'product_metadata': {'name': 'Indigo Nation Men Printed Black T-shirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 43967,
#   'product_metadata': {'name': 'DKNY Women Red Delicious Perfume',
#    'gender': 'Women',
#    'master_category': 'Personal Care',
#    'sub_category': 'Fragrance',
#    'article_type': 'Perfume and Body Mist',
#    'base_color': 'Red',
#    'season': 'Spring',
#    'year': 2017,
#    'usage': 'Casual'}},
#  {'product_id': 28456,
#   'product_metadata': {'name': 'Urban Yoga Women Blue Skirt With Leggings',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Bottomwear',
#    'article_type': 'Skirts',
#    'base_color': 'Blue',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Sports'}},
#  {'product_id': 34009,
#   'product_metadata': {'name': 'Gini and Jony Girls Black Top',
#    'gender': 'Girls',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tops',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 19311,
#   'product_metadata': {'name': 'Nike Men Air Rift MTR White Casual Shoe',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Casual Shoes',
#    'base_color': 'White',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 42089,
#   'product_metadata': {'name': 'ADIDAS Men White Corona Sports Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Sports Shoes',
#    'base_color': 'White',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Sports'}},
#  {'product_id': 22950,
#   'product_metadata': {'name': 'Fastrack Unisex Black Dial Watch 9915PP13',
#    'gender': 'Unisex',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'Black',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 49461,
#   'product_metadata': {'name': 'Vans Men Blue Era Scilla Plaid Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Casual Shoes',
#    'base_color': 'Blue',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 8746,
#   'product_metadata': {'name': 'Crocs Kids Navy Blue Clogs',
#    'gender': 'Unisex',
#    'master_category': 'Footwear',
#    'sub_category': 'Flip Flops',
#    'article_type': 'Flip Flops',
#    'base_color': 'Navy Blue',
#    'season': 'Summer',
#    'year': 2015,
#    'usage': 'Casual'}},
#  {'product_id': 9694,
#   'product_metadata': {'name': 'Classic Polo Men Vulcan White Polo Tshirts',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'White',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 23882,
#   'product_metadata': {'name': 'Fila Men Destiny Grey Sports Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Sports Shoes',
#    'base_color': 'Grey',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Sports'}},
#  {'product_id': 34835,
#   'product_metadata': {'name': 'ADIDAS Men Blue Chill Sports Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Sports Shoes',
#    'base_color': 'Blue',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Sports'}},
#  {'product_id': 15984,
#   'product_metadata': {'name': 'Turtle Check Men Yellow Shirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Shirts',
#    'base_color': 'Yellow',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 41268,
#   'product_metadata': {'name': 'Arrow Men Black Wallet',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Wallets',
#    'article_type': 'Wallets',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 11518,
#   'product_metadata': {'name': 'Catwalk Women Gun Metal Grey Heels',
#    'gender': 'Women',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Heels',
#    'base_color': 'Grey',
#    'season': 'Winter',
#    'year': 2015,
#    'usage': 'Casual'}},
#  {'product_id': 14856,
#   'product_metadata': {'name': 'United Colors of Benetton Women Solid Beige Wallets',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Wallets',
#    'article_type': 'Wallets',
#    'base_color': 'Beige',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 33648,
#   'product_metadata': {'name': 'Lotto Men Ridge Brown Sandals',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Sandal',
#    'article_type': 'Sandals',
#    'base_color': 'Brown',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 59297,
#   'product_metadata': {'name': 'U.S. Polo Assn. Men White & Navy Blue Shirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Shirts',
#    'base_color': 'White',
#    'season': 'Fall',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 28032,
#   'product_metadata': {'name': 'Jockey ELANCE Men Bikini White Brief 1005',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Innerwear',
#    'article_type': 'Briefs',
#    'base_color': 'White',
#    'season': 'Summer',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 27846,
#   'product_metadata': {'name': 'Scullers For Her Charcoal Blazer',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Blazers',
#    'base_color': 'Charcoal',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Formal'}},
#  {'product_id': 26994,
#   'product_metadata': {'name': 'Jealous 21 Women Black Jeans',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Bottomwear',
#    'article_type': 'Jeans',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 49839,
#   'product_metadata': {'name': 'iPanema Women Red Flip Flops',
#    'gender': 'Women',
#    'master_category': 'Footwear',
#    'sub_category': 'Flip Flops',
#    'article_type': 'Flip Flops',
#    'base_color': 'Red',
#    'season': 'Winter',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 31923,
#   'product_metadata': {'name': 'Fabindia Women Blue Silk Sling Bag',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Bags',
#    'article_type': 'Handbags',
#    'base_color': 'Blue',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 2618,
#   'product_metadata': {'name': 'Carlton London Women Silver Wedge Sandal',
#    'gender': 'Women',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Flats',
#    'base_color': 'Silver',
#    'season': 'Spring',
#    'year': 2010,
#    'usage': 'Casual'}},
#  {'product_id': 54588,
#   'product_metadata': {'name': 'Sushilas Women Printed Green Kurta',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Kurtas',
#    'base_color': 'Green',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Ethnic'}},
#  {'product_id': 49005,
#   'product_metadata': {'name': 'Lucera Women Silver Ring',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Jewellery',
#    'article_type': 'Ring',
#    'base_color': 'Silver',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 8322,
#   'product_metadata': {'name': "Doodle Boy's Route 66 Biker Blue Teen Kidswear",
#    'gender': 'Boys',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Blue',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 13841,
#   'product_metadata': {'name': 'ADIDAS Unisex Three Small Dials White Watches',
#    'gender': 'Unisex',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'White',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 28200,
#   'product_metadata': {'name': 'Ray-Ban Men Active Lifestyle Copper Sunglasses',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Eyewear',
#    'article_type': 'Sunglasses',
#    'base_color': 'Copper',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 12993,
#   'product_metadata': {'name': 'ADIDAS Kids Adispeed Black Sports Shoes',
#    'gender': 'Unisex',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Sports Shoes',
#    'base_color': 'Black',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Sports'}},
#  {'product_id': 7158,
#   'product_metadata': {'name': 'Scullers Men  Green Check Shirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Shirts',
#    'base_color': 'Green',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 18495,
#   'product_metadata': {'name': 'Puma Men Fashion Cat White Slipper',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Sandal',
#    'article_type': 'Sandals',
#    'base_color': 'White',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 8110,
#   'product_metadata': {'name': 'Fastrack Men Economy 2 Analg Black Watch',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'Black',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 19547,
#   'product_metadata': {'name': 'United Colors of Benetton Men Solid Blue Sweatshirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Sweatshirts',
#    'base_color': 'Blue',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 7964,
#   'product_metadata': {'name': "Puma Men's Large Logo Graphic Black T-shirt",
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Black',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Sports'}},
#  {'product_id': 36934,
#   'product_metadata': {'name': 'Giorgio Armani Women Idole Perfume',
#    'gender': 'Women',
#    'master_category': 'Personal Care',
#    'sub_category': 'Fragrance',
#    'article_type': 'Perfume and Body Mist',
#    'base_color': 'Gold',
#    'season': 'Spring',
#    'year': 2017,
#    'usage': 'Casual'}},
#  {'product_id': 39140,
#   'product_metadata': {'name': 'Aneri Women Black & Maroon Salwar Suit',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Apparel Set',
#    'article_type': 'Kurta Sets',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Ethnic'}},
#  {'product_id': 20851,
#   'product_metadata': {'name': 'Spice Art Women Ribbon Embroidery Red Clutch',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Bags',
#    'article_type': 'Clutches',
#    'base_color': 'Red',
#    'season': 'Winter',
#    'year': 2015,
#    'usage': 'Casual'}},
#  {'product_id': 41866,
#   'product_metadata': {'name': 'Estd. 1977 Men Beige & Green Sandals',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Sandal',
#    'article_type': 'Sandals',
#    'base_color': 'Beige',
#    'season': 'Fall',
#    'year': 2015,
#    'usage': 'Casual'}},
#  {'product_id': 58177,
#   'product_metadata': {'name': 'Rocky S Women Brown Handbag',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Bags',
#    'article_type': 'Handbags',
#    'base_color': 'Brown',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 44528,
#   'product_metadata': {'name': 'Coolers Men Black Sandals',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Sandal',
#    'article_type': 'Sandals',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 16392,
#   'product_metadata': {'name': 'Levis Men Check Red Shirts',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Shirts',
#    'base_color': 'Red',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 51455,
#   'product_metadata': {'name': 'Tonga Women Pink Printed Shrug',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Shrug',
#    'base_color': 'Pink',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 50587,
#   'product_metadata': {'name': 'Chromozome Men Grey Briefs',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Innerwear',
#    'article_type': 'Briefs',
#    'base_color': 'Grey',
#    'season': 'Summer',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 17240,
#   'product_metadata': {'name': 'U.S. Polo Assn. Men Stripes Black  Polo Tshirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Black',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 47530,
#   'product_metadata': {'name': 'Portia Women Copper-Toned & Brown Sandals',
#    'gender': 'Women',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Flats',
#    'base_color': 'Copper',
#    'season': 'Winter',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 6617,
#   'product_metadata': {'name': 'Spykar Men Black and white Check Shirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Shirts',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 12732,
#   'product_metadata': {'name': 'Nike Unisex Swoosh Black Backpack',
#    'gender': 'Unisex',
#    'master_category': 'Accessories',
#    'sub_category': 'Bags',
#    'article_type': 'Backpacks',
#    'base_color': 'Black',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Sports'}},
#  {'product_id': 3365,
#   'product_metadata': {'name': "Myntra Men's Brain Black T-shirt",
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 42042,
#   'product_metadata': {'name': 'Nike Men Air Relentless 2 MSL White Sports Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Sports Shoes',
#    'base_color': 'White',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Sports'}},
#  {'product_id': 23849,
#   'product_metadata': {'name': 'ADIDAS Men Black Anzo Breeze Casual Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Casual Shoes',
#    'base_color': 'Black',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 43190,
#   'product_metadata': {'name': 'Fastrack Women White Dial Watch',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'White',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 48578,
#   'product_metadata': {'name': 'Revv Men Steel Bracelet',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Jewellery',
#    'article_type': 'Bracelet',
#    'base_color': 'Steel',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 30462,
#   'product_metadata': {'name': 'Lovable Women All Day Long Black Bra',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Innerwear',
#    'article_type': 'Bra',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2014,
#    'usage': 'Casual'}},
#  {'product_id': 18208,
#   'product_metadata': {'name': 'Manchester United Men Solid White Cap',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Headwear',
#    'article_type': 'Caps',
#    'base_color': 'White',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 54127,
#   'product_metadata': {'name': 'Rocia Women Black Heels',
#    'gender': 'Women',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Heels',
#    'base_color': 'Black',
#    'season': 'Winter',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 10065,
#   'product_metadata': {'name': 'Puma Men ducati logo tee Yellow Tshirts',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Yellow',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 24250,
#   'product_metadata': {'name': 'Numero Uno Men White Casual Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Casual Shoes',
#    'base_color': 'White',
#    'season': 'Fall',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 32335,
#   'product_metadata': {'name': 'Q&Q Men Silver-Toned Dial Analogue Watch Q252J404Y',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'Silver',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 25382,
#   'product_metadata': {'name': 'Levis Men White Innerwear Vest',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Innerwear',
#    'article_type': 'Innerwear Vests',
#    'base_color': 'White',
#    'season': 'Summer',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 56670,
#   'product_metadata': {'name': 'Maxima Men Black Dial Watch',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'Black',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 5092,
#   'product_metadata': {'name': "Wrangler Men's Minstrel Shoulder Loop Purple T-shirt",
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Purple',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 10859,
#   'product_metadata': {'name': 'Wrangler Men Furious Rides Navy Blue T-Shirts',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Navy Blue',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 59638,
#   'product_metadata': {'name': 'FNF Green Wedding Collection Sari',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Saree',
#    'article_type': 'Sarees',
#    'base_color': 'Green',
#    'season': 'Fall',
#    'year': 2012,
#    'usage': 'Ethnic'}},
#  {'product_id': 15517,
#   'product_metadata': {'name': 'Rockport Men LLandro Red Casual Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Casual Shoes',
# ...
#    'article_type': 'Watches',
#    'base_color': 'Black',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 59609,
#   'product_metadata': {'name': 'FNF Khaki Collection for Wedding Sari',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Saree',
#    'article_type': 'Sarees',
#    'base_color': 'Khaki',
#    'season': 'Fall',
#    'year': 2012,
#    'usage': 'Ethnic'}},
#  {'product_id': 15526,
#   'product_metadata': {'name': 'Rockport Women Jeanie Oneband Brown Flats',
#    'gender': 'Women',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Heels',
#    'base_color': 'Brown',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 21713,
#   'product_metadata': {'name': 'Fossil Men Blue Dial Chronograph Watch CH2752',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'Blue',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 44384,
#   'product_metadata': {'name': 'Spinz Women Enchante Deo',
#    'gender': 'Women',
#    'master_category': 'Personal Care',
#    'sub_category': 'Fragrance',
#    'article_type': 'Deodorant',
#    'base_color': 'White',
#    'season': 'Spring',
#    'year': 2017,
#    'usage': 'Casual'}},
#  {'product_id': 37676,
#   'product_metadata': {'name': 'American Tourister Unisex Black Backpack',
#    'gender': 'Unisex',
#    'master_category': 'Accessories',
#    'sub_category': 'Bags',
#    'article_type': 'Backpacks',
#    'base_color': 'Black',
#    'season': 'Winter',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 6626,
#   'product_metadata': {'name': "ADIDAS Men's Canon Dialect Blue Yellow Shoe",
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Sports Shoes',
#    'base_color': 'Blue',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Sports'}},
#  {'product_id': 47501,
#   'product_metadata': {'name': 'Footfun Kids Unisex Red Shoes',
#    'gender': 'Unisex',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Casual Shoes',
#    'base_color': 'Red',
#    'season': 'Fall',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 17271,
#   'product_metadata': {'name': 'U.S. Polo Assn. Men Stripes DK.Grey Polo Tshirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Grey',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 23044,
#   'product_metadata': {'name': 'Arrow Woman Brown Jeggings',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Bottomwear',
#    'article_type': 'Leggings',
#    'base_color': 'Brown',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 22196,
#   'product_metadata': {'name': 'Timberland Men Black Casual Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Casual Shoes',
#    'base_color': 'Black',
#    'season': 'Fall',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 51464,
#   'product_metadata': {'name': 'Tonga Women Olive Top',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tops',
#    'base_color': 'Olive',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 54116,
#   'product_metadata': {'name': 'Rocia Women Maroon Sandals',
#    'gender': 'Women',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Heels',
#    'base_color': 'Maroon',
#    'season': 'Winter',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 30453,
#   'product_metadata': {'name': 'Deni Yo Men White Jeans',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Bottomwear',
#    'article_type': 'Jeans',
#    'base_color': 'White',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 2286,
#   'product_metadata': {'name': 'Nike Men Black Sweatshirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Sweatshirts',
#    'base_color': 'Black',
#    'season': 'Fall',
#    'year': 2010,
#    'usage': 'Sports'}},
#  {'product_id': 23878,
#   'product_metadata': {'name': 'Fila Women Sleeker Green Check Casual Shoes',
#    'gender': 'Women',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Casual Shoes',
#    'base_color': 'Green',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 48549,
#   'product_metadata': {'name': 'Wrangler Women Black Belt',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Belts',
#    'article_type': 'Belts',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 42073,
#   'product_metadata': {'name': 'American Tourister Men Black Wallet',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Wallets',
#    'article_type': 'Wallets',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 31581,
#   'product_metadata': {'name': 'Mark Taylor Men Printed Blue T-shirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Blue',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 3354,
#   'product_metadata': {'name': "Myntra Men's I Give 100 Percent Work White T-shirt",
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'White',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 26536,
#   'product_metadata': {'name': 'ID Men White Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Casual Shoes',
#    'base_color': 'White',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 12703,
#   'product_metadata': {'name': 'Nike Women Downshifter White Sports Shoes',
#    'gender': 'Women',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Sports Shoes',
#    'base_color': 'White',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Sports'}},
#  {'product_id': 24605,
#   'product_metadata': {'name': 'Vishudh Women Pink Churidar Kurta with Dupatta',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Apparel Set',
#    'article_type': 'Kurta Sets',
#    'base_color': 'Pink',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Ethnic'}},
#  {'product_id': 10430,
#   'product_metadata': {'name': 'Flying Machine Men Ydc Blue Shirts',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Shirts',
#    'base_color': 'Blue',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 56225,
#   'product_metadata': {'name': 'SDL by Sweet Dreams Men Black & Grey Pyjama Set',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Loungewear and Nightwear',
#    'article_type': 'Night suits',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 39388,
#   'product_metadata': {'name': 'Peter England Men Black Jeans',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Bottomwear',
#    'article_type': 'Jeans',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 14090,
#   'product_metadata': {'name': 'Flying Machine Men Stripes Blue Polo Tshirts',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Blue',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 53757,
#   'product_metadata': {'name': 'Puma Women Speeder Wns Ind White Sports Shoes',
#    'gender': 'Women',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Sports Shoes',
#    'base_color': 'White',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Sports'}},
#  {'product_id': 37212,
#   'product_metadata': {'name': 'United Colors of Benetton Men Pink Shirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Shirts',
#    'base_color': 'Pink',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 4515,
#   'product_metadata': {'name': "Puma Men's Tarun White Silver Red Shoe",
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Sports Shoes',
#    'base_color': 'White',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Sports'}},
#  {'product_id': 45632,
#   'product_metadata': {'name': 'Park Avenue Men Grey Melange Briefs',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Innerwear',
#    'article_type': 'Briefs',
#    'base_color': 'Grey Melange',
#    'season': 'Summer',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 51000,
#   'product_metadata': {'name': 'Enamor Maroon Bra FB06',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Innerwear',
#    'article_type': 'Bra',
#    'base_color': 'Maroon',
#    'season': 'Summer',
#    'year': 2018,
#    'usage': 'Casual'}},
#  {'product_id': 7390,
#   'product_metadata': {'name': 'Red Tape Men Brown Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Formal Shoes',
#    'base_color': 'Brown',
#    'season': 'Winter',
#    'year': 2018,
#    'usage': 'Formal'}},
#  {'product_id': 35545,
#   'product_metadata': {'name': 'Enroute Teens Brown Sandals',
#    'gender': 'Girls',
#    'master_category': 'Footwear',
#    'sub_category': 'Sandal',
#    'article_type': 'Sandals',
#    'base_color': 'Brown',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 6242,
#   'product_metadata': {'name': "Lee Women's Rihana Purple T-shirt",
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Purple',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 47165,
#   'product_metadata': {'name': 'Peter England Men Black Belt',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Belts',
#    'article_type': 'Belts',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 17615,
#   'product_metadata': {'name': 'Doodle Boys living Upto White Tshirt',
#    'gender': 'Boys',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'White',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Casual'}},
#  {'product_id': 48911,
#   'product_metadata': {'name': 'Lucera Women Silver Pendant with Chain',
#    'gender': 'Women',
#    'master_category': 'Accessories',
#    'sub_category': 'Jewellery',
#    'article_type': 'Pendant',
#    'base_color': 'Silver',
#    'season': 'Summer',
#    'year': 2013,
#    'usage': 'Casual'}},
#  {'product_id': 29926,
#   'product_metadata': {'name': 'Police Men Black Dial Watch PL12778MSU-61',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'Black',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 42417,
#   'product_metadata': {'name': 'American Tourister Unisex Purple Messenger Bag',
#    'gender': 'Unisex',
#    'master_category': 'Accessories',
#    'sub_category': 'Accessories',
#    'article_type': 'Messenger Bag',
#    'base_color': 'Purple',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 3730,
#   'product_metadata': {'name': 'CSK Mens Fangear Yellow Jersey',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Yellow',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Sports'}},
#  {'product_id': 26152,
#   'product_metadata': {'name': 'John Miller Men Striped Grey Trousers',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Bottomwear',
#    'article_type': 'Trousers',
#    'base_color': 'Grey',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Formal'}},
#  {'product_id': 12367,
#   'product_metadata': {'name': 'Reid & Taylor Men White Shirt',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Shirts',
#    'base_color': 'White',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Formal'}},
#  {'product_id': 54572,
#   'product_metadata': {'name': 'Sushilas Women Multi Coloured Kurta',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Kurtas',
#    'base_color': 'Pink',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Ethnic'}},
#  {'product_id': 27080,
#   'product_metadata': {'name': 'Catwalk Women Silver Flats',
#    'gender': 'Women',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Heels',
#    'base_color': 'Silver',
#    'season': 'Winter',
#    'year': 2015,
#    'usage': 'Casual'}},
#  {'product_id': 30037,
#   'product_metadata': {'name': 'SKAGEN DENMARK Men Silver-Toned Dial Watch 233LSS',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'Silver',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 46285,
#   'product_metadata': {'name': '109F Women Multi Coloured Dress',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Dress',
#    'article_type': 'Dresses',
#    'base_color': 'Multi',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Casual'}},
#  {'product_id': 12969,
#   'product_metadata': {'name': 'ADIDAS Men Snova Glide Blue Sports Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Sports Shoes',
#    'base_color': 'Blue',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Sports'}},
#  {'product_id': 35777,
#   'product_metadata': {'name': 'Force 10 Men Black & Green Sports Shoes',
#    'gender': 'Men',
#    'master_category': 'Footwear',
#    'sub_category': 'Shoes',
#    'article_type': 'Sports Shoes',
#    'base_color': 'Black',
#    'season': 'Summer',
#    'year': 2012,
#    'usage': 'Sports'}},
#  {'product_id': 51232,
#   'product_metadata': {'name': 'Satya Paul Women Green Printed Kaftan',
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Kurtas',
#    'base_color': 'Green',
#    'season': 'Fall',
#    'year': 2012,
#    'usage': 'Ethnic'}},
#  {'product_id': 17427,
#   'product_metadata': {'name': 'CASIO G-Shock Men White Analogue & Digital Watch G274',
#    'gender': 'Men',
#    'master_category': 'Accessories',
#    'sub_category': 'Watches',
#    'article_type': 'Watches',
#    'base_color': 'White',
#    'season': 'Winter',
#    'year': 2016,
#    'usage': 'Casual'}},
#  {'product_id': 9804,
#   'product_metadata': {'name': 'John Miller Men Black Checks Shirts',
#    'gender': 'Men',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Shirts',
#    'base_color': 'Black',
#    'season': 'Fall',
#    'year': 2011,
#    'usage': 'Formal'}},
#  {'product_id': 23612,
#   'product_metadata': {'name': 'Nike Fragrances Women Sensual Touch Perfume',
#    'gender': 'Women',
#    'master_category': 'Personal Care',
#    'sub_category': 'Fragrance',
#    'article_type': 'Perfume and Body Mist',
#    'base_color': 'Pink',
#    'season': 'Spring',
#    'year': 2017,
#    'usage': 'Casual'}},
#  {'product_id': 6070,
#   'product_metadata': {'name': "UCB Women's Young Pigment Blue T-shirt",
#    'gender': 'Women',
#    'master_category': 'Apparel',
#    'sub_category': 'Topwear',
#    'article_type': 'Tshirts',
#    'base_color': 'Blue',
#    'season': 'Summer',
#    'year': 2011,
#    'usage': 'Casual'}}]

# %%
merged = [vd | md for vd, md in zip(vector_dict, products_meta) if vd["product_id"] == md["product_id"]]

# %%
merged[0].keys()
# Out:
# dict_keys(['text_vector', 'img_vector', 'product_id', 'product_metadata'])

# %%
with open("./products.json", "w") as f:
    json.dump(merged, f)

# %%
import os
os.getcwd()
# Out:
# '/Users/robert.shelton/Documents/redis-product-search/data'

# %%
from redis.asyncio import Redis
from redisvl.schema import IndexSchema
from redisvl.index import AsyncSearchIndex

dir_path = "../backend/productsearch/db/schema"
schema = IndexSchema.from_yaml(os.path.join(dir_path, "products.yml"))
client = Redis.from_url("redis://localhost:6379")
index = AsyncSearchIndex(schema, client)

# %%
await index.client.ping()
# Out:
# True

# %%
product_id = 10062
res = await index.client.hget(f"{index.schema.index.prefix}:{product_id}", "img_vector")
res
# Out:
# b'+.9=\x88M\xb6<\x0cl9=\x87z\xe5=\xcc=\xd4>\xd1,\xb9?)\xe3\x89>oc>>\x16X\x94?\xb0N\x1b?PqT=I\xe8\xc7<P\xb3\x1c?\x1aQ\xbf<\x8d\x1c\xc2;\xc0\xd1\x8b?\xcei\xca>\x00\x00\x00\x00\x87l\xa4>^\xa4b>s\x15\xc6=n\xb3L?/\x98N@\x1b\xd7\xe5?9\xa6\r>b\xfa\xce>r2\x12?\x82\x7f\x82@\xcc\xfas;\xf7\x1bJ?\xea\xa7\x8d?\xf6J\x05=\xff-\x94>}\xb3\xdc?V\x89@@9\x8dV?oy)?A\xaf_>\x81\xff\x1f?p\x03\xd5>\x1d\xd8\x86?\x99\x15\xb7=\xd5~n=\xb3\xb1\xb0?\xa6\xc2\r@<\xcd\x7f=\x99\x1b\x90>\xd0Z\x07=\x7f\x8c6?\xe6E\x08?\x92;B@\x85\x96 ?\xee\x97\xc0>o\xf2Z?4\x99\x99?\x9ev\xcc>MF\xd1>8@\x11@\xc0}\xbe>\x9a\xb4.?\xfb\x8aD=s\xcc\xa8?\
# %%
index.schema.index.prefix
# Out:
# 'product'

# %%
import json
with open("./products.json", "r") as f:
    products = json.load(f)

# %%
import pandas as pd

img_lookup = pd.read_csv("./fashion-dataset/images.csv")

img_lookup.head()
# Out:
#     filename                                               link
# 0  15970.jpg  http://assets.myntassets.com/v1/images/style/p...
# 1  39386.jpg  http://assets.myntassets.com/v1/images/style/p...
# 2  59263.jpg  http://assets.myntassets.com/v1/images/style/p...
# 3  21379.jpg  http://assets.myntassets.com/v1/images/style/p...
# 4  53759.jpg  http://assets.myntassets.com/v1/images/style/p...

# %%
for p in products:
    filename = f"{p['product_id']}.jpg"
    img_url = img_lookup[img_lookup["filename"] == filename].iloc[0]["link"]
    if not img_url:
        print("no image!")
    p["product_metadata"]["img_url"] = img_url

# %%
products[0]["product_metadata"]
# Out:
# {'name': 'Turtle Check Men Navy Blue Shirt',
#  'gender': 'Men',
#  'master_category': 'Apparel',
#  'sub_category': 'Topwear',
#  'article_type': 'Shirts',
#  'base_color': 'Navy Blue',
#  'season': 'Fall',
#  'year': 2011,
#  'usage': 'Casual',
#  'img_url': 'http://assets.myntassets.com/v1/images/style/properties/7a5b82d1372a7a5c6de67ae7a314fd91_images.jpg'}

# %%
products[0]["product_id"]
# Out:
# 15970

# %%
with open("./products.json", "w") as f:
    json.dump(products, f)

# %%
[
    {
        "product_id": "56670",
        "name": "Maxima Men Black Dial Watch",
        "gender": "Men",
        "category": "Accessories",
        "img_url": "http://assets.myntassets.com/v1/images/style/properties/Maxima-Men-Black-Dial-Watch_c427a05e5f1d545b2b03ad86b4960427_images.jpg",
        "text_vector": "\t\"ݪTೇӀN\u001e6Ɠ=<Ɂ<j~<\f,w\u0015=ׇ:?\r\u0015/1<|<=\u0016=O\u0015+'={=)،.H\"=_\u0011<\u001br)=S\u00019\b\u0014=%=bv<:e\b<)We|bnEt<T\u00067\u0003;G<2<!\u0006û'\"=F!BQ=ȼ:2$g:\n;8tއB9%4\bh7,\u0003\u001d<刻&\u001d[<ǣ<R\u001d=<D=-<Ά=-><\u0011d\\[<k}\u0014C<ٽ\u0015\u000ee\u0012A\u00038\u0007;ϼ\f~[\u000191!<xi;;\u0018mn:8X=\u001fkJ<G=Bb\u0016]\u0013;\u000fV<K=\\<$;h@\np;RjӳOP7<B9ʼ\u001b@S\u001c=F:\t<,\u0004i\u0018\u0005_\u0001<=Kb\u0011<{<[@<\u0010_:=9A+\u000b=Ąw</^Zrʕyo(\\P<]\u001bg\u0018~\u001a\u0003\u00119x;\f<^r\u0004<y%=\u0002\"ܼ4;G93oJa=\u0000<o{<#\u000e\u0015Rm\"\u0005=7=n=\u0001\u0007E\u0018RV^&<`5=\u0000[\u0013\nJ=VN<쁼_Cd\u0017=#HD<=<U\u0017)=\u0012jq\u0014<\u0007<a%:=aqJo<\u0017*\u0014=y4;~\u001ev\u001eV2<